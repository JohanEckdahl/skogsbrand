# %%
import re
import sqlite3
import pandas as pd
class Database():
    
    def __init__(self, db_name): self.connection = self.connect(db_name)
    
    def read(self, sql): pass
    
    def connect(self,db_name): pass
    
    def insert(self, table_name, dataframe): print("yaa, inserted, get some!")
        
    def disconnect(self): pass
        
    def __del__(self): self.disconnect()
        

class SQLiteDB(Database):
    
    def connect(self,db_name): return sqlite3.connect(db_name)
    
    def read(self, sql): return pd.read_sql_query(sql, self.connection,
                                                  index_col="id")
    
    def insert(self, table_name, dataframe):
        dataframe.to_sql(table_name, self.connection,
                         if_exists="append", index = False)
        
    def disconnect(self): self.connection.close()
    
    
name = '/Users/johan/Documents/Programming/skogsbrand/db.sqlite3'
db = SQLiteDB(name)
df = db.read("SELECT * FROM fires_fire")
db.disconnect
display(df)
# Out:
#         NAMN       Producent  GISHektar              Lannamn    CenterX  \
# id
# 1       None  Skogsstyrelsen          1         Dalarnas län  6817084.0
# 2       None  Skogsstyrelsen          0        Jämtlands län  7014643.0
# 3       None  Skogsstyrelsen         25      Norrbottens län  7451801.0
# 4       None  Skogsstyrelsen          0      Norrbottens län  7436253.0
# 5       None  Skogsstyrelsen          7      Norrbottens län  7413872.0
# 6       None  Skogsstyrelsen          0      Norrbottens län  7420692.0
# 7       None  Skogsstyrelsen          1      Norrbottens län  7428291.0
# 8       None  Skogsstyrelsen          2      Norrbottens län  7419231.0
# 9       None  Skogsstyrelsen         11      Norrbottens län  7413932.0
# 10      None  Skogsstyrelsen          0      Norrbottens län  7408632.0
# 11      None  Skogsstyrelsen         10      Norrbottens län  7385089.0
# 12      None  Skogsstyrelsen          4      Norrbottens län  7362472.0
# 13      None  Skogsstyrelsen          1      Norrbottens län  7346198.0
# 14      None  Skogsstyrelsen          1      Norrbottens län  7332414.0
# 15      None  Skogsstyrelsen          3      Norrbottens län  7285641.0
# 16      None  Skogsstyrelsen         97    Västerbottens län  7234732.0
# 17      None  Skogsstyrelsen          1    Västerbottens län  7197206.0
# 18      None  Skogsstyrelsen          0    Västerbottens län  7180967.0
# 19      None  Skogsstyrelsen          6    Västerbottens län  7171921.0
# 20      None  Skogsstyrelsen          4    Västerbottens län  7141638.0
# 21      None  Skogsstyrelsen          0    Västerbottens län  7117167.0
# 22      None  Skogsstyrelsen          1    Västerbottens län  7110876.0
# 23      None  Skogsstyrelsen          0        Jämtlands län  7134913.0
# 24      None  Skogsstyrelsen          1    Västerbottens län  7111942.0
# 25      None  Skogsstyrelsen          1    Västerbottens län  7116381.0
# 26      None  Skogsstyrelsen          3  Västernorrlands län  7094456.0
# 27      None  Skogsstyrelsen          2  Västernorrlands län  7089537.0
# 28      None  Skogsstyrelsen          1  Västernorrlands län  7082187.0
# 29      None  Skogsstyrelsen          1    Västerbottens län  7086968.0
# 30      None  Skogsstyrelsen          3    Västerbottens län  7068280.0
# ..       ...             ...        ...                  ...        ...
# 296     None            None          1           Kalmar län  6382560.0
# 297     None            None          3  Västernorrlands län  7032310.0
# 298     None            None          3           Kalmar län  6369726.0
# 299     None            None          0           Kalmar län  6346985.0
# 300     None            None          1  Västernorrlands län  6899610.0
# 301     None            None          4          Uppsala län  6717574.0
# 302     None            None          2    Västerbottens län  7120718.0
# 303     None            None          2        Värmlands län  6613227.0
# 304     None            None          0           Kalmar län  6371423.0
# 305     None            None          1           Kalmar län  6252547.0
# 306     None            None          7          Uppsala län  6612335.0
# 307     None            None          0           Kalmar län  6400533.0
# 308     None            None          1       Stockholms län  6582101.0
# 309     None            None          2       Gävleborgs län  6721601.0
# 310  Pålgård            None        222        Jämtlands län  7000663.0
# 311     None            None         16     Västmanlands län  6617857.0
# 312     None            None          4        Jämtlands län  7020714.0
# 313     None            None          1        Jämtlands län  7107110.0
# 314     None            None          1        Jämtlands län  7145479.0
# 315     None            None          1        Jämtlands län  6980186.0
# 316     None            None          1  Västernorrlands län  7080028.0
# 317     None            None          5  Västernorrlands län  7082288.0
# 318     None            None          1  Västernorrlands län  7018240.0
# 319     None            None          2  Västernorrlands län  7071626.0
# 320     None            None          0  Västernorrlands län  7042641.0
# 321     None            None          3  Västernorrlands län  7038797.0
# 322     None            None          2          Uppsala län  6671392.0
# 323     None            None         14      Norrbottens län  7406022.0
# 324     None            None         31    Västerbottens län  7100306.0
# 325  Ryvålen  Skogsstyrelsen          0        Jämtlands län  6905240.0
#
#       CenterY Aktualitet       Kommunnamn                         Metod  \
# id
# 1    505854.0       None          Rättvik  Manuell kartering - satellit
# 2    520492.0       None          Ragunda  Manuell kartering - satellit
# 3    795352.0       None        Gällivare  Manuell kartering - satellit
# 4    786486.0       None        Gällivare  Manuell kartering - satellit
# 5    784183.0       None        Gällivare  Manuell kartering - satellit
# 6    835344.0       None        Överkalix  Manuell kartering - satellit
# 7    890227.0       None       Övertorneå  Manuell kartering - satellit
# 8    681153.0       None         Jokkmokk  Manuell kartering - satellit
# 9    680313.0       None         Jokkmokk  Manuell kartering - satellit
# 10   701085.0       None         Jokkmokk  Manuell kartering - satellit
# 11   761983.0       None         Jokkmokk  Manuell kartering - satellit
# 12   743216.0       None         Jokkmokk  Manuell kartering - satellit
# 13   825294.0       None            Luleå  Manuell kartering - satellit
# 14   720730.0       None         Jokkmokk  Manuell kartering - satellit
# 15   758705.0       None            Piteå  Manuell kartering - satellit
# 16   754306.0       None       Skellefteå  Manuell kartering - satellit
# 17   771349.0       None       Skellefteå  Manuell kartering - satellit
# 18   686168.0       None         Lycksele  Manuell kartering - satellit
# 19   641184.0       None         Lycksele  Manuell kartering - satellit
# 20   669472.0       None         Lycksele  Manuell kartering - satellit
# 21   617501.0       None            Åsele  Manuell kartering - satellit
# 22   628490.0       None            Åsele  Manuell kartering - satellit
# 23   508479.0       None        Strömsund  Manuell kartering - satellit
# 24   669077.0       None            Åsele  Manuell kartering - satellit
# 25   680579.0       None         Lycksele  Manuell kartering - satellit
# 26   662332.0       None     Örnsköldsvik  Manuell kartering - satellit
# 27   645706.0       None     Örnsköldsvik  Manuell kartering - satellit
# 28   672724.0       None     Örnsköldsvik  Manuell kartering - satellit
# 29   716508.0       None         Bjurholm  Manuell kartering - satellit
# 30   740177.0       None             Umeå  Manuell kartering - satellit
# ..        ...        ...              ...                           ...
# 296  580428.0       None        Västervik  Manuell kartering - satellit
# 297  687603.0       None     Örnsköldsvik  Manuell kartering - satellit
# 298  556080.0       None        Hultsfred  Manuell kartering - satellit
# 299  571367.0       None       Oskarshamn  Manuell kartering - satellit
# 300  596041.0       None        Sundsvall  Manuell kartering - satellit
# 301  656805.0       None            Tierp  Manuell kartering - satellit
# 302  748757.0       None             Umeå  Manuell kartering - satellit
# 303  372012.0       None           Arvika  Manuell kartering - satellit
# 304  566213.0       None        Hultsfred  Manuell kartering - satellit
# 305  551105.0       None           Torsås  Manuell kartering - satellit
# 306  638644.0       None             Håbo  Manuell kartering - satellit
# 307  575099.0       None        Västervik  Manuell kartering - satellit
# 308  699417.0       None           Värmdö  Manuell kartering - satellit
# 309  626427.0       None            Gävle  Manuell kartering - satellit
# 310  570852.0       None          Ragunda  Manuell kartering - satellit
# 311  536877.0       None  Skinnskatteberg  Manuell kartering - satellit
# 312  559210.0       None          Ragunda             Avgränsat med GPS
# 313  505735.0       None        Strömsund  Manuell kartering - satellit
# 314  465402.0       None        Strömsund  Manuell kartering - satellit
# 315  578568.0       None          Ragunda  Manuell kartering - satellit
# 316  648947.0       None     Örnsköldsvik  Manuell kartering - satellit
# 317  589328.0       None        Sollefteå  Manuell kartering - satellit
# 318  622779.0       None        Sollefteå  Manuell kartering - satellit
# 319  671376.0       None     Örnsköldsvik  Manuell kartering - satellit
# 320  698741.0       None     Örnsköldsvik  Manuell kartering - satellit
# 321  628583.0       None     Örnsköldsvik  Manuell kartering - satellit
# 322  690391.0       None        Östhammar  Manuell kartering - satellit
# 323  831966.0       None        Överkalix  Manuell kartering - satellit
# 324  731717.0       None           Vännäs  Manuell kartering - satellit
# 325  428097.0       None       Härjedalen             Inmätning med GPS
#
#                   Kvalitet                                          Kommentar  \
# id
# 1           Granskad - God                 Ser inte ut att ha brunnit så hårt
# 2           Granskad - God                                               None
# 3           Granskad - God                  Redan karterad med dålig kvalitet
# 4           Granskad - God                                               None
# 5           Granskad - God                                               None
# 6           Granskad - God                                               None
# 7           Granskad - God                                               None
# 8           Granskad - God                                               None
# 9           Granskad - God                                               None
# 10          Granskad - God                                               None
# 11          Granskad - God                                               None
# 12          Granskad - God                                               None
# 13          Granskad - God                                               None
# 14          Granskad - God                                               None
# 15          Granskad - God                                               None
# 16          Granskad - God  Utökning av UngBrandomrade_180810. Trol återan...
# 17          Granskad - God                                               None
# 18          Granskad - God                         Långt från larmkoordinaten
# 19          Granskad - God                                               None
# 20          Granskad - God                                               None
# 21          Granskad - God                                               None
# 22          Granskad - God                                               None
# 23          Granskad - God                                               None
# 24          Granskad - God                                               None
# 25          Granskad - God                                               None
# 26          Granskad - God                                               None
# 27          Granskad - God                            2 km från larmkoordinat
# 28          Granskad - God                                               None
# 29          Granskad - God                                               None
# 30          Granskad - God                                               None
# ..                     ...                                                ...
# 296         Granskad - God                                               None
# 297         Granskad - God                                               None
# 298         Granskad - God                                               None
# 299         Granskad - God                                               None
# 300         Granskad - God                                               None
# 301         Granskad - God                                               None
# 302         Granskad - God                                               None
# 303         Granskad - God                                               None
# 304         Granskad - God                                               None
# 305         Granskad - God                                               None
# 306         Granskad - God                                               None
# 307         Granskad - God                                               None
# 308         Granskad - God                                               None
# 309         Granskad - God                                               None
# 310         Granskad - God  Copernicus. Korr med GPS och noggrannare satbi...
# 311         Granskad - God                              Tips från Magnus Lind
# 312  Granskad - Mycket god                                  Avgränsat med GPS
# 313         Granskad - God              Brand syns i satellitbild från 180714
# 314         Granskad - God                                               None
# 315         Granskad - God  Kant i hygge, brand syns i satellitbild från 1...
# 316         Granskad - God               Brand ses i satellitbild från 180714
# 317         Granskad - God  Brandlåga ses i satellitbild 180714 (larmtid 1...
# 318         Granskad - God                                               None
# 319         Granskad - God                                               None
# 320         Granskad - God                                               None
# 321         Granskad - God                                               None
# 322         Granskad - God                                               None
# 323         Granskad - God                                               None
# 324         Granskad - God  Brand utmed järnväg, består av flera mindre om...
# 325  Granskad - Mycket god                 Inmätt av länsstyrelsen i Jämtland
#
#      OBJECTID    Laddatum  Lopnr    shape_STAr    shape_STLe  quality  \
# id
# 1           1  2018-11-12    0.0  9.321945e+03    396.439838      NaN
# 2           2  2018-11-12    0.0  3.467797e+03    231.143215      0.0
# 3           3  2018-11-12    0.0  2.528263e+05   2094.482984      2.0
# 4           4  2018-11-12    0.0  2.226246e+03    215.198973      NaN
# 5           5  2018-11-12    0.0  7.058243e+04   1137.325233      0.0
# 6           6  2018-11-12    0.0  2.211575e+03    173.596825      NaN
# 7           7  2018-11-12    0.0  9.508280e+03    367.876498      1.0
# 8           8  2018-11-12    0.0  1.962633e+04    521.936447      3.0
# 9           9  2018-11-12    0.0  1.099044e+05   1483.892367      1.0
# 10         10  2018-11-12    0.0  3.310582e+03    211.633487      NaN
# 11         11  2018-11-12    0.0  9.959233e+04   1353.843407      3.0
# 12         12  2018-11-12    0.0  3.995148e+04   1123.683699      0.0
# 13         13  2018-11-12    0.0  1.096048e+04    432.920681      3.0
# 14         14  2018-11-12    0.0  5.491051e+03    274.812726      NaN
# 15         15  2018-11-12    0.0  2.677835e+04    790.263685      NaN
# 16         16  2018-11-12    0.0  9.748019e+05   5030.334674      1.0
# 17         17  2018-11-12    0.0  1.011243e+04    471.423463      NaN
# 18         18  2018-11-12    0.0  2.576057e+03    200.358786      NaN
# 19         19  2018-11-12    0.0  6.010459e+04   1276.283297      3.0
# 20         20  2018-11-12    0.0  3.950807e+04    878.248993      0.0
# 21         21  2018-11-12    0.0  6.745608e+02    107.873096      NaN
# 22         22  2018-11-12    0.0  1.102564e+04    384.241052      NaN
# 23         23  2018-11-12    0.0  3.604273e+03    226.532259      NaN
# 24         24  2018-11-12    0.0  1.087516e+04    405.279760      NaN
# 25         25  2018-11-12    0.0  6.135074e+03    402.240168      2.0
# 26         26  2018-11-12    0.0  2.920097e+04    641.279195      1.0
# 27         27  2018-11-12    0.0  1.989007e+04    541.271854      NaN
# 28         28  2018-11-12    0.0  5.223768e+03    273.604378      NaN
# 29         29  2018-11-12    0.0  1.380414e+04    443.689975      NaN
# 30         30  2018-11-12    0.0  2.939230e+04    715.219658      3.0
# ..        ...         ...    ...           ...           ...      ...
# 296       296  2018-11-12    0.0  5.713572e+03    304.615031      1.0
# 297       297  2018-11-12    0.0  3.277100e+04    720.715078      3.0
# 298       298  2018-11-12    0.0  3.093218e+04    743.195610      1.0
# 299       299  2018-11-12    0.0  2.728830e+03    190.609014      NaN
# 300       300  2018-11-12    0.0  1.341759e+04    439.482767      NaN
# 301       301  2018-11-12    0.0  3.585982e+04   1025.572766      1.0
# 302       302  2018-11-12    0.0  2.198368e+04    734.898537      NaN
# 303       303  2018-11-12    0.0  2.022447e+04    534.734811      3.0
# 304       304  2018-11-12    0.0  3.605893e+03    260.622494      NaN
# 305       305  2018-11-12    0.0  9.669890e+03    382.735377      NaN
# 306       306  2018-11-12    0.0  6.996574e+04   1229.905352      0.0
# 307       307  2018-11-12    0.0  4.401801e+03    245.086148      NaN
# 308       308  2018-11-12    0.0  5.804886e+03    298.321344      NaN
# 309       309  2018-11-12    0.0  1.997884e+04    655.908651      NaN
# 310       310  2018-11-12    0.0  2.217775e+06   8204.163393      1.0
# 311       311  2018-11-12    0.0  1.577082e+05   4821.446777      0.0
# 312       312  2018-11-12    0.0  3.927383e+04   1006.003705      1.0
# 313       313  2018-11-12    0.0  5.646546e+03    361.527112      NaN
# 314       314  2018-11-12    0.0  1.106260e+04    507.455603      NaN
# 315       315  2018-11-12    0.0  6.872255e+03    340.603363      NaN
# 316       316  2018-11-12    0.0  9.845811e+03    411.485873      NaN
# 317       317  2018-11-12    0.0  5.399286e+04    953.771099      3.0
# 318       318  2018-11-12    0.0  7.710732e+03    366.932389      NaN
# 319       319  2018-11-12    0.0  2.223753e+04    873.319131      NaN
# 320       320  2018-11-12    0.0  2.405816e+03    182.339489      NaN
# 321       321  2018-11-12    0.0  2.676707e+04    830.960996      3.0
# 322       322  2018-11-12    0.0  2.457781e+04    910.150043      NaN
# 323       323  2018-11-12    0.0  1.380035e+05   1788.394542      1.0
# 324       324  2018-11-12    0.0  3.070429e+05   7953.669207      3.0
# 325       325  2018-11-12    0.0  1.483482e+06  21471.566299      NaN
#
#                                                summary
# id
# 1                                                 None
# 2                                     not checked oops
# 3    This fire is located in Norrbotten and quite c...
# 4                                                 None
# 5                                              Logging
# 6                                                 None
# 7                                      Planned logging
# 8                                         Pretty good!
# 9                            Might be too much logging
# 10                                                None
# 11                                         Looks good!
# 12                                         Logged 2007
# 13                                          Looks good
# 14                                                None
# 15                                                None
# 16                                    Too much logging
# 17                                                None
# 18                                                None
# 19                          long walk however, 1.77 km
# 20                                            cut down
# 21                                                None
# 22                                                None
# 23                                                None
# 24                                                None
# 25               On a small slope with planned logging
# 26                                        future plans
# 27                                                None
# 28                                                None
# 29                                                None
# 30                                          Uber nice!
# ..                                                 ...
# 296                        Inside planned logging area
# 297                  Looks good, but lesser tree cover
# 298                                     Future Logging
# 299                                               None
# 300                                               None
# 301  The clearing history is confusing and it might...
# 302                                               None
# 303                                         seems good
# 304                                               None
# 305                                               None
# 306                                    Planned logging
# 307                                               None
# 308                                               None
# 309                                               None
# 310                   Looks interesting, but too hilly
# 311                                     Recent logging
# 312    Looks like a good spot but don't see fire on IR
# 313                                               None
# 314                                               None
# 315                                               None
# 316                                               None
# 317                        open flame, less tree cover
# 318                                               None
# 319                                               None
# 320                                               None
# 321                              Long walk, about 1 km
# 322                                               None
# 323                          Might be too much logging
# 324                                  Looks really nice
# 325                                               None
#
# [325 rows x 18 columns]

# %%
for index, row in df.iterrows():
    if row['quality'] >= 2:

        string = """
        \newpage
        \subsubsection{Fire !!id}

        \begin{table}[h!]
        \begin{tabular}{@{}lllll@{}}
        \toprule
        id   & Name   & Hectare   & CenterX   & CenterY   \\ \midrule
        # !!id & !!name & !!hectare & !!centerX & !!centerY
        \end{tabular}
        \end{table}

        \begin{table}[h!]
        \begin{tabular}{@{}llllll@{}}
        \toprule
        Patch & X         & Y         & ParkingX & ParkingX & Walk(m) \\ \midrule
        1     & !!burntX1 & !!burntY1 & !!burntParkX1 & !!burntParkX1 & !!Walk1 \\
        2     & !!burntX2 & !!burntY2 & !!burntParkX2 & !!burntParkX2 & !!Walk2 \\
        3     & !!burntX3 & !!burntY3 & !!burntParkX3 & !!burntParkY3 & !!Walk3 \\
        4     & !!burntX4 & !!burntY4 & !!burntParkX4 & !!burntParkY4 & !!Walk4 \\
        5     & !!burntX5 & !!burntY5 & !!burntParkX5 & !!burntParkY5 & !!Walk5 \\ \bottomrule
        \end{tabular}
        \end{table}


        \begin{table}[h!]
        \begin{tabular}{@{}llllll@{}}
        \toprule
        Patch & X         & Y         & ParkingX & ParkingY & Walk(m) \\ \midrule
        1     & !!unburntX1 & !!unburntY1 & !!unburntParkX1 & !!unburntParkX1 & !!Walk1 \\
        2     & !!unburntX2 & !!unburntY2 & !!unburntParkX2 & !!unburntParkX2 & !!Walk2 \\
        3     & !!unburntX3 & !!unburntY3 & !!unburntParkX3 & !!unburntParkY3 & !!Walk3 \\
        4     & !!unburntX4 & !!unburntY4 & !!unburntParkX4 & !!unburntParkY4 & !!Walk4 \\
        5     & !!unburntX5 & !!unburntY5 & !!unburntParkX5 & !!unburntParkY5 & !!Walk5 \\ \bottomrule
        \end{tabular}
        \end{table}

        """

        string.replace("!!id", str(index))
        print(string)
    exit
# Out:
#
# ewpage
#         \subsubsection{Fire !!id}
#
# egin{table}[h!]
# egin{tabular}{@{}lllll@{}}
#         	oprule
#         id   & Name   & Hectare   & CenterX   & CenterY   \ \midrule
#         !!id & !!name & !!hectare & !!centerX & !!centerY
#         \end{tabular}
#         \end{table}
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingX & Walk(m) \ \midrule
#         1     & !!burntX1 & !!burntY1 & !!burntParkX1 & !!burntParkX1 & !!Walk1 \
#         2     & !!burntX2 & !!burntY2 & !!burntParkX2 & !!burntParkX2 & !!Walk2 \
#         3     & !!burntX3 & !!burntY3 & !!burntParkX3 & !!burntParkY3 & !!Walk3 \
#         4     & !!burntX4 & !!burntY4 & !!burntParkX4 & !!burntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingY & Walk(m) \ \midrule
#         1     & !!unburntX1 & !!unburntY1 & !!unburntParkX1 & !!unburntParkX1 & !!Walk1 \
#         2     & !!unburntX2 & !!unburntY2 & !!unburntParkX2 & !!unburntParkX2 & !!Walk2 \
#         3     & !!unburntX3 & !!unburntY3 & !!unburntParkX3 & !!unburntParkY3 & !!Walk3 \
#         4     & !!unburntX4 & !!unburntY4 & !!unburntParkX4 & !!unburntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
#
#
# ewpage
#         \subsubsection{Fire !!id}
#
# egin{table}[h!]
# egin{tabular}{@{}lllll@{}}
#         	oprule
#         id   & Name   & Hectare   & CenterX   & CenterY   \ \midrule
#         !!id & !!name & !!hectare & !!centerX & !!centerY
#         \end{tabular}
#         \end{table}
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingX & Walk(m) \ \midrule
#         1     & !!burntX1 & !!burntY1 & !!burntParkX1 & !!burntParkX1 & !!Walk1 \
#         2     & !!burntX2 & !!burntY2 & !!burntParkX2 & !!burntParkX2 & !!Walk2 \
#         3     & !!burntX3 & !!burntY3 & !!burntParkX3 & !!burntParkY3 & !!Walk3 \
#         4     & !!burntX4 & !!burntY4 & !!burntParkX4 & !!burntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingY & Walk(m) \ \midrule
#         1     & !!unburntX1 & !!unburntY1 & !!unburntParkX1 & !!unburntParkX1 & !!Walk1 \
#         2     & !!unburntX2 & !!unburntY2 & !!unburntParkX2 & !!unburntParkX2 & !!Walk2 \
#         3     & !!unburntX3 & !!unburntY3 & !!unburntParkX3 & !!unburntParkY3 & !!Walk3 \
#         4     & !!unburntX4 & !!unburntY4 & !!unburntParkX4 & !!unburntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
#
#
# ewpage
#         \subsubsection{Fire !!id}
#
# egin{table}[h!]
# egin{tabular}{@{}lllll@{}}
#         	oprule
#         id   & Name   & Hectare   & CenterX   & CenterY   \ \midrule
#         !!id & !!name & !!hectare & !!centerX & !!centerY
#         \end{tabular}
#         \end{table}
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingX & Walk(m) \ \midrule
#         1     & !!burntX1 & !!burntY1 & !!burntParkX1 & !!burntParkX1 & !!Walk1 \
#         2     & !!burntX2 & !!burntY2 & !!burntParkX2 & !!burntParkX2 & !!Walk2 \
#         3     & !!burntX3 & !!burntY3 & !!burntParkX3 & !!burntParkY3 & !!Walk3 \
#         4     & !!burntX4 & !!burntY4 & !!burntParkX4 & !!burntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingY & Walk(m) \ \midrule
#         1     & !!unburntX1 & !!unburntY1 & !!unburntParkX1 & !!unburntParkX1 & !!Walk1 \
#         2     & !!unburntX2 & !!unburntY2 & !!unburntParkX2 & !!unburntParkX2 & !!Walk2 \
#         3     & !!unburntX3 & !!unburntY3 & !!unburntParkX3 & !!unburntParkY3 & !!Walk3 \
#         4     & !!unburntX4 & !!unburntY4 & !!unburntParkX4 & !!unburntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
#
#
# ewpage
#         \subsubsection{Fire !!id}
#
# egin{table}[h!]
# egin{tabular}{@{}lllll@{}}
#         	oprule
#         id   & Name   & Hectare   & CenterX   & CenterY   \ \midrule
#         !!id & !!name & !!hectare & !!centerX & !!centerY
#         \end{tabular}
#         \end{table}
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingX & Walk(m) \ \midrule
#         1     & !!burntX1 & !!burntY1 & !!burntParkX1 & !!burntParkX1 & !!Walk1 \
#         2     & !!burntX2 & !!burntY2 & !!burntParkX2 & !!burntParkX2 & !!Walk2 \
#         3     & !!burntX3 & !!burntY3 & !!burntParkX3 & !!burntParkY3 & !!Walk3 \
#         4     & !!burntX4 & !!burntY4 & !!burntParkX4 & !!burntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingY & Walk(m) \ \midrule
#         1     & !!unburntX1 & !!unburntY1 & !!unburntParkX1 & !!unburntParkX1 & !!Walk1 \
#         2     & !!unburntX2 & !!unburntY2 & !!unburntParkX2 & !!unburntParkX2 & !!Walk2 \
#         3     & !!unburntX3 & !!unburntY3 & !!unburntParkX3 & !!unburntParkY3 & !!Walk3 \
#         4     & !!unburntX4 & !!unburntY4 & !!unburntParkX4 & !!unburntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
#
#
# ewpage
#         \subsubsection{Fire !!id}
#
# egin{table}[h!]
# egin{tabular}{@{}lllll@{}}
#         	oprule
#         id   & Name   & Hectare   & CenterX   & CenterY   \ \midrule
#         !!id & !!name & !!hectare & !!centerX & !!centerY
#         \end{tabular}
#         \end{table}
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingX & Walk(m) \ \midrule
#         1     & !!burntX1 & !!burntY1 & !!burntParkX1 & !!burntParkX1 & !!Walk1 \
#         2     & !!burntX2 & !!burntY2 & !!burntParkX2 & !!burntParkX2 & !!Walk2 \
#         3     & !!burntX3 & !!burntY3 & !!burntParkX3 & !!burntParkY3 & !!Walk3 \
#         4     & !!burntX4 & !!burntY4 & !!burntParkX4 & !!burntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingY & Walk(m) \ \midrule
#         1     & !!unburntX1 & !!unburntY1 & !!unburntParkX1 & !!unburntParkX1 & !!Walk1 \
#         2     & !!unburntX2 & !!unburntY2 & !!unburntParkX2 & !!unburntParkX2 & !!Walk2 \
#         3     & !!unburntX3 & !!unburntY3 & !!unburntParkX3 & !!unburntParkY3 & !!Walk3 \
#         4     & !!unburntX4 & !!unburntY4 & !!unburntParkX4 & !!unburntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
#
#
# ewpage
#         \subsubsection{Fire !!id}
#
# egin{table}[h!]
# egin{tabular}{@{}lllll@{}}
#         	oprule
#         id   & Name   & Hectare   & CenterX   & CenterY   \ \midrule
#         !!id & !!name & !!hectare & !!centerX & !!centerY
#         \end{tabular}
#         \end{table}
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingX & Walk(m) \ \midrule
#         1     & !!burntX1 & !!burntY1 & !!burntParkX1 & !!burntParkX1 & !!Walk1 \
#         2     & !!burntX2 & !!burntY2 & !!burntParkX2 & !!burntParkX2 & !!Walk2 \
#         3     & !!burntX3 & !!burntY3 & !!burntParkX3 & !!burntParkY3 & !!Walk3 \
#         4     & !!burntX4 & !!burntY4 & !!burntParkX4 & !!burntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingY & Walk(m) \ \midrule
#         1     & !!unburntX1 & !!unburntY1 & !!unburntParkX1 & !!unburntParkX1 & !!Walk1 \
#         2     & !!unburntX2 & !!unburntY2 & !!unburntParkX2 & !!unburntParkX2 & !!Walk2 \
#         3     & !!unburntX3 & !!unburntY3 & !!unburntParkX3 & !!unburntParkY3 & !!Walk3 \
#         4     & !!unburntX4 & !!unburntY4 & !!unburntParkX4 & !!unburntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
#
#
# ewpage
#         \subsubsection{Fire !!id}
#
# egin{table}[h!]
# egin{tabular}{@{}lllll@{}}
#         	oprule
#         id   & Name   & Hectare   & CenterX   & CenterY   \ \midrule
#         !!id & !!name & !!hectare & !!centerX & !!centerY
#         \end{tabular}
#         \end{table}
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingX & Walk(m) \ \midrule
#         1     & !!burntX1 & !!burntY1 & !!burntParkX1 & !!burntParkX1 & !!Walk1 \
#         2     & !!burntX2 & !!burntY2 & !!burntParkX2 & !!burntParkX2 & !!Walk2 \
#         3     & !!burntX3 & !!burntY3 & !!burntParkX3 & !!burntParkY3 & !!Walk3 \
#         4     & !!burntX4 & !!burntY4 & !!burntParkX4 & !!burntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingY & Walk(m) \ \midrule
#         1     & !!unburntX1 & !!unburntY1 & !!unburntParkX1 & !!unburntParkX1 & !!Walk1 \
#         2     & !!unburntX2 & !!unburntY2 & !!unburntParkX2 & !!unburntParkX2 & !!Walk2 \
#         3     & !!unburntX3 & !!unburntY3 & !!unburntParkX3 & !!unburntParkY3 & !!Walk3 \
#         4     & !!unburntX4 & !!unburntY4 & !!unburntParkX4 & !!unburntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
#
#
# ewpage
#         \subsubsection{Fire !!id}
#
# egin{table}[h!]
# egin{tabular}{@{}lllll@{}}
#         	oprule
#         id   & Name   & Hectare   & CenterX   & CenterY   \ \midrule
#         !!id & !!name & !!hectare & !!centerX & !!centerY
#         \end{tabular}
#         \end{table}
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingX & Walk(m) \ \midrule
#         1     & !!burntX1 & !!burntY1 & !!burntParkX1 & !!burntParkX1 & !!Walk1 \
#         2     & !!burntX2 & !!burntY2 & !!burntParkX2 & !!burntParkX2 & !!Walk2 \
#         3     & !!burntX3 & !!burntY3 & !!burntParkX3 & !!burntParkY3 & !!Walk3 \
#         4     & !!burntX4 & !!burntY4 & !!burntParkX4 & !!burntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingY & Walk(m) \ \midrule
#         1     & !!unburntX1 & !!unburntY1 & !!unburntParkX1 & !!unburntParkX1 & !!Walk1 \
#         2     & !!unburntX2 & !!unburntY2 & !!unburntParkX2 & !!unburntParkX2 & !!Walk2 \
#         3     & !!unburntX3 & !!unburntY3 & !!unburntParkX3 & !!unburntParkY3 & !!Walk3 \
#         4     & !!unburntX4 & !!unburntY4 & !!unburntParkX4 & !!unburntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
#
#
# ewpage
#         \subsubsection{Fire !!id}
#
# egin{table}[h!]
# egin{tabular}{@{}lllll@{}}
#         	oprule
#         id   & Name   & Hectare   & CenterX   & CenterY   \ \midrule
#         !!id & !!name & !!hectare & !!centerX & !!centerY
#         \end{tabular}
#         \end{table}
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingX & Walk(m) \ \midrule
#         1     & !!burntX1 & !!burntY1 & !!burntParkX1 & !!burntParkX1 & !!Walk1 \
#         2     & !!burntX2 & !!burntY2 & !!burntParkX2 & !!burntParkX2 & !!Walk2 \
#         3     & !!burntX3 & !!burntY3 & !!burntParkX3 & !!burntParkY3 & !!Walk3 \
#         4     & !!burntX4 & !!burntY4 & !!burntParkX4 & !!burntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingY & Walk(m) \ \midrule
#         1     & !!unburntX1 & !!unburntY1 & !!unburntParkX1 & !!unburntParkX1 & !!Walk1 \
#         2     & !!unburntX2 & !!unburntY2 & !!unburntParkX2 & !!unburntParkX2 & !!Walk2 \
#         3     & !!unburntX3 & !!unburntY3 & !!unburntParkX3 & !!unburntParkY3 & !!Walk3 \
#         4     & !!unburntX4 & !!unburntY4 & !!unburntParkX4 & !!unburntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
#
#
# ewpage
#         \subsubsection{Fire !!id}
#
# egin{table}[h!]
# egin{tabular}{@{}lllll@{}}
#         	oprule
#         id   & Name   & Hectare   & CenterX   & CenterY   \ \midrule
#         !!id & !!name & !!hectare & !!centerX & !!centerY
#         \end{tabular}
#         \end{table}
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingX & Walk(m) \ \midrule
#         1     & !!burntX1 & !!burntY1 & !!burntParkX1 & !!burntParkX1 & !!Walk1 \
#         2     & !!burntX2 & !!burntY2 & !!burntParkX2 & !!burntParkX2 & !!Walk2 \
#         3     & !!burntX3 & !!burntY3 & !!burntParkX3 & !!burntParkY3 & !!Walk3 \
#         4     & !!burntX4 & !!burntY4 & !!burntParkX4 & !!burntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingY & Walk(m) \ \midrule
#         1     & !!unburntX1 & !!unburntY1 & !!unburntParkX1 & !!unburntParkX1 & !!Walk1 \
#         2     & !!unburntX2 & !!unburntY2 & !!unburntParkX2 & !!unburntParkX2 & !!Walk2 \
#         3     & !!unburntX3 & !!unburntY3 & !!unburntParkX3 & !!unburntParkY3 & !!Walk3 \
#         4     & !!unburntX4 & !!unburntY4 & !!unburntParkX4 & !!unburntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
#
#
# ewpage
#         \subsubsection{Fire !!id}
#
# egin{table}[h!]
# egin{tabular}{@{}lllll@{}}
#         	oprule
#         id   & Name   & Hectare   & CenterX   & CenterY   \ \midrule
#         !!id & !!name & !!hectare & !!centerX & !!centerY
#         \end{tabular}
#         \end{table}
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingX & Walk(m) \ \midrule
#         1     & !!burntX1 & !!burntY1 & !!burntParkX1 & !!burntParkX1 & !!Walk1 \
#         2     & !!burntX2 & !!burntY2 & !!burntParkX2 & !!burntParkX2 & !!Walk2 \
#         3     & !!burntX3 & !!burntY3 & !!burntParkX3 & !!burntParkY3 & !!Walk3 \
#         4     & !!burntX4 & !!burntY4 & !!burntParkX4 & !!burntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingY & Walk(m) \ \midrule
#         1     & !!unburntX1 & !!unburntY1 & !!unburntParkX1 & !!unburntParkX1 & !!Walk1 \
#         2     & !!unburntX2 & !!unburntY2 & !!unburntParkX2 & !!unburntParkX2 & !!Walk2 \
#         3     & !!unburntX3 & !!unburntY3 & !!unburntParkX3 & !!unburntParkY3 & !!Walk3 \
#         4     & !!unburntX4 & !!unburntY4 & !!unburntParkX4 & !!unburntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
#
#
# ewpage
#         \subsubsection{Fire !!id}
#
# egin{table}[h!]
# egin{tabular}{@{}lllll@{}}
#         	oprule
#         id   & Name   & Hectare   & CenterX   & CenterY   \ \midrule
#         !!id & !!name & !!hectare & !!centerX & !!centerY
#         \end{tabular}
#         \end{table}
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingX & Walk(m) \ \midrule
#         1     & !!burntX1 & !!burntY1 & !!burntParkX1 & !!burntParkX1 & !!Walk1 \
#         2     & !!burntX2 & !!burntY2 & !!burntParkX2 & !!burntParkX2 & !!Walk2 \
#         3     & !!burntX3 & !!burntY3 & !!burntParkX3 & !!burntParkY3 & !!Walk3 \
#         4     & !!burntX4 & !!burntY4 & !!burntParkX4 & !!burntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingY & Walk(m) \ \midrule
#         1     & !!unburntX1 & !!unburntY1 & !!unburntParkX1 & !!unburntParkX1 & !!Walk1 \
#         2     & !!unburntX2 & !!unburntY2 & !!unburntParkX2 & !!unburntParkX2 & !!Walk2 \
#         3     & !!unburntX3 & !!unburntY3 & !!unburntParkX3 & !!unburntParkY3 & !!Walk3 \
#         4     & !!unburntX4 & !!unburntY4 & !!unburntParkX4 & !!unburntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
#
#
# ewpage
#         \subsubsection{Fire !!id}
#
# egin{table}[h!]
# egin{tabular}{@{}lllll@{}}
#         	oprule
#         id   & Name   & Hectare   & CenterX   & CenterY   \ \midrule
#         !!id & !!name & !!hectare & !!centerX & !!centerY
#         \end{tabular}
#         \end{table}
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingX & Walk(m) \ \midrule
#         1     & !!burntX1 & !!burntY1 & !!burntParkX1 & !!burntParkX1 & !!Walk1 \
#         2     & !!burntX2 & !!burntY2 & !!burntParkX2 & !!burntParkX2 & !!Walk2 \
#         3     & !!burntX3 & !!burntY3 & !!burntParkX3 & !!burntParkY3 & !!Walk3 \
#         4     & !!burntX4 & !!burntY4 & !!burntParkX4 & !!burntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingY & Walk(m) \ \midrule
#         1     & !!unburntX1 & !!unburntY1 & !!unburntParkX1 & !!unburntParkX1 & !!Walk1 \
#         2     & !!unburntX2 & !!unburntY2 & !!unburntParkX2 & !!unburntParkX2 & !!Walk2 \
#         3     & !!unburntX3 & !!unburntY3 & !!unburntParkX3 & !!unburntParkY3 & !!Walk3 \
#         4     & !!unburntX4 & !!unburntY4 & !!unburntParkX4 & !!unburntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
#
#
# ewpage
#         \subsubsection{Fire !!id}
#
# egin{table}[h!]
# egin{tabular}{@{}lllll@{}}
#         	oprule
#         id   & Name   & Hectare   & CenterX   & CenterY   \ \midrule
#         !!id & !!name & !!hectare & !!centerX & !!centerY
#         \end{tabular}
#         \end{table}
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingX & Walk(m) \ \midrule
#         1     & !!burntX1 & !!burntY1 & !!burntParkX1 & !!burntParkX1 & !!Walk1 \
#         2     & !!burntX2 & !!burntY2 & !!burntParkX2 & !!burntParkX2 & !!Walk2 \
#         3     & !!burntX3 & !!burntY3 & !!burntParkX3 & !!burntParkY3 & !!Walk3 \
#         4     & !!burntX4 & !!burntY4 & !!burntParkX4 & !!burntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingY & Walk(m) \ \midrule
#         1     & !!unburntX1 & !!unburntY1 & !!unburntParkX1 & !!unburntParkX1 & !!Walk1 \
#         2     & !!unburntX2 & !!unburntY2 & !!unburntParkX2 & !!unburntParkX2 & !!Walk2 \
#         3     & !!unburntX3 & !!unburntY3 & !!unburntParkX3 & !!unburntParkY3 & !!Walk3 \
#         4     & !!unburntX4 & !!unburntY4 & !!unburntParkX4 & !!unburntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
#
#
# ewpage
#         \subsubsection{Fire !!id}
#
# egin{table}[h!]
# egin{tabular}{@{}lllll@{}}
#         	oprule
#         id   & Name   & Hectare   & CenterX   & CenterY   \ \midrule
#         !!id & !!name & !!hectare & !!centerX & !!centerY
#         \end{tabular}
#         \end{table}
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingX & Walk(m) \ \midrule
#         1     & !!burntX1 & !!burntY1 & !!burntParkX1 & !!burntParkX1 & !!Walk1 \
#         2     & !!burntX2 & !!burntY2 & !!burntParkX2 & !!burntParkX2 & !!Walk2 \
#         3     & !!burntX3 & !!burntY3 & !!burntParkX3 & !!burntParkY3 & !!Walk3 \
#         4     & !!burntX4 & !!burntY4 & !!burntParkX4 & !!burntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingY & Walk(m) \ \midrule
#         1     & !!unburntX1 & !!unburntY1 & !!unburntParkX1 & !!unburntParkX1 & !!Walk1 \
#         2     & !!unburntX2 & !!unburntY2 & !!unburntParkX2 & !!unburntParkX2 & !!Walk2 \
#         3     & !!unburntX3 & !!unburntY3 & !!unburntParkX3 & !!unburntParkY3 & !!Walk3 \
#         4     & !!unburntX4 & !!unburntY4 & !!unburntParkX4 & !!unburntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
#
#
# ewpage
#         \subsubsection{Fire !!id}
#
# egin{table}[h!]
# egin{tabular}{@{}lllll@{}}
#         	oprule
#         id   & Name   & Hectare   & CenterX   & CenterY   \ \midrule
#         !!id & !!name & !!hectare & !!centerX & !!centerY
#         \end{tabular}
#         \end{table}
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingX & Walk(m) \ \midrule
#         1     & !!burntX1 & !!burntY1 & !!burntParkX1 & !!burntParkX1 & !!Walk1 \
#         2     & !!burntX2 & !!burntY2 & !!burntParkX2 & !!burntParkX2 & !!Walk2 \
#         3     & !!burntX3 & !!burntY3 & !!burntParkX3 & !!burntParkY3 & !!Walk3 \
#         4     & !!burntX4 & !!burntY4 & !!burntParkX4 & !!burntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingY & Walk(m) \ \midrule
#         1     & !!unburntX1 & !!unburntY1 & !!unburntParkX1 & !!unburntParkX1 & !!Walk1 \
#         2     & !!unburntX2 & !!unburntY2 & !!unburntParkX2 & !!unburntParkX2 & !!Walk2 \
#         3     & !!unburntX3 & !!unburntY3 & !!unburntParkX3 & !!unburntParkY3 & !!Walk3 \
#         4     & !!unburntX4 & !!unburntY4 & !!unburntParkX4 & !!unburntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
#
#
# ewpage
#         \subsubsection{Fire !!id}
#
# egin{table}[h!]
# egin{tabular}{@{}lllll@{}}
#         	oprule
#         id   & Name   & Hectare   & CenterX   & CenterY   \ \midrule
#         !!id & !!name & !!hectare & !!centerX & !!centerY
#         \end{tabular}
#         \end{table}
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingX & Walk(m) \ \midrule
#         1     & !!burntX1 & !!burntY1 & !!burntParkX1 & !!burntParkX1 & !!Walk1 \
#         2     & !!burntX2 & !!burntY2 & !!burntParkX2 & !!burntParkX2 & !!Walk2 \
#         3     & !!burntX3 & !!burntY3 & !!burntParkX3 & !!burntParkY3 & !!Walk3 \
#         4     & !!burntX4 & !!burntY4 & !!burntParkX4 & !!burntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingY & Walk(m) \ \midrule
#         1     & !!unburntX1 & !!unburntY1 & !!unburntParkX1 & !!unburntParkX1 & !!Walk1 \
#         2     & !!unburntX2 & !!unburntY2 & !!unburntParkX2 & !!unburntParkX2 & !!Walk2 \
#         3     & !!unburntX3 & !!unburntY3 & !!unburntParkX3 & !!unburntParkY3 & !!Walk3 \
#         4     & !!unburntX4 & !!unburntY4 & !!unburntParkX4 & !!unburntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
#
#
# ewpage
#         \subsubsection{Fire !!id}
#
# egin{table}[h!]
# egin{tabular}{@{}lllll@{}}
#         	oprule
#         id   & Name   & Hectare   & CenterX   & CenterY   \ \midrule
#         !!id & !!name & !!hectare & !!centerX & !!centerY
#         \end{tabular}
#         \end{table}
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingX & Walk(m) \ \midrule
#         1     & !!burntX1 & !!burntY1 & !!burntParkX1 & !!burntParkX1 & !!Walk1 \
#         2     & !!burntX2 & !!burntY2 & !!burntParkX2 & !!burntParkX2 & !!Walk2 \
#         3     & !!burntX3 & !!burntY3 & !!burntParkX3 & !!burntParkY3 & !!Walk3 \
#         4     & !!burntX4 & !!burntY4 & !!burntParkX4 & !!burntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingY & Walk(m) \ \midrule
#         1     & !!unburntX1 & !!unburntY1 & !!unburntParkX1 & !!unburntParkX1 & !!Walk1 \
#         2     & !!unburntX2 & !!unburntY2 & !!unburntParkX2 & !!unburntParkX2 & !!Walk2 \
#         3     & !!unburntX3 & !!unburntY3 & !!unburntParkX3 & !!unburntParkY3 & !!Walk3 \
#         4     & !!unburntX4 & !!unburntY4 & !!unburntParkX4 & !!unburntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
#
#
# ewpage
#         \subsubsection{Fire !!id}
#
# egin{table}[h!]
# egin{tabular}{@{}lllll@{}}
#         	oprule
#         id   & Name   & Hectare   & CenterX   & CenterY   \ \midrule
#         !!id & !!name & !!hectare & !!centerX & !!centerY
#         \end{tabular}
#         \end{table}
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingX & Walk(m) \ \midrule
#         1     & !!burntX1 & !!burntY1 & !!burntParkX1 & !!burntParkX1 & !!Walk1 \
#         2     & !!burntX2 & !!burntY2 & !!burntParkX2 & !!burntParkX2 & !!Walk2 \
#         3     & !!burntX3 & !!burntY3 & !!burntParkX3 & !!burntParkY3 & !!Walk3 \
#         4     & !!burntX4 & !!burntY4 & !!burntParkX4 & !!burntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingY & Walk(m) \ \midrule
#         1     & !!unburntX1 & !!unburntY1 & !!unburntParkX1 & !!unburntParkX1 & !!Walk1 \
#         2     & !!unburntX2 & !!unburntY2 & !!unburntParkX2 & !!unburntParkX2 & !!Walk2 \
#         3     & !!unburntX3 & !!unburntY3 & !!unburntParkX3 & !!unburntParkY3 & !!Walk3 \
#         4     & !!unburntX4 & !!unburntY4 & !!unburntParkX4 & !!unburntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
#
#
# ewpage
#         \subsubsection{Fire !!id}
#
# egin{table}[h!]
# egin{tabular}{@{}lllll@{}}
#         	oprule
#         id   & Name   & Hectare   & CenterX   & CenterY   \ \midrule
#         !!id & !!name & !!hectare & !!centerX & !!centerY
#         \end{tabular}
#         \end{table}
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingX & Walk(m) \ \midrule
#         1     & !!burntX1 & !!burntY1 & !!burntParkX1 & !!burntParkX1 & !!Walk1 \
#         2     & !!burntX2 & !!burntY2 & !!burntParkX2 & !!burntParkX2 & !!Walk2 \
#         3     & !!burntX3 & !!burntY3 & !!burntParkX3 & !!burntParkY3 & !!Walk3 \
#         4     & !!burntX4 & !!burntY4 & !!burntParkX4 & !!burntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingY & Walk(m) \ \midrule
#         1     & !!unburntX1 & !!unburntY1 & !!unburntParkX1 & !!unburntParkX1 & !!Walk1 \
#         2     & !!unburntX2 & !!unburntY2 & !!unburntParkX2 & !!unburntParkX2 & !!Walk2 \
#         3     & !!unburntX3 & !!unburntY3 & !!unburntParkX3 & !!unburntParkY3 & !!Walk3 \
#         4     & !!unburntX4 & !!unburntY4 & !!unburntParkX4 & !!unburntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
#
#
# ewpage
#         \subsubsection{Fire !!id}
#
# egin{table}[h!]
# egin{tabular}{@{}lllll@{}}
#         	oprule
#         id   & Name   & Hectare   & CenterX   & CenterY   \ \midrule
#         !!id & !!name & !!hectare & !!centerX & !!centerY
#         \end{tabular}
#         \end{table}
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingX & Walk(m) \ \midrule
#         1     & !!burntX1 & !!burntY1 & !!burntParkX1 & !!burntParkX1 & !!Walk1 \
#         2     & !!burntX2 & !!burntY2 & !!burntParkX2 & !!burntParkX2 & !!Walk2 \
#         3     & !!burntX3 & !!burntY3 & !!burntParkX3 & !!burntParkY3 & !!Walk3 \
#         4     & !!burntX4 & !!burntY4 & !!burntParkX4 & !!burntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingY & Walk(m) \ \midrule
#         1     & !!unburntX1 & !!unburntY1 & !!unburntParkX1 & !!unburntParkX1 & !!Walk1 \
#         2     & !!unburntX2 & !!unburntY2 & !!unburntParkX2 & !!unburntParkX2 & !!Walk2 \
#         3     & !!unburntX3 & !!unburntY3 & !!unburntParkX3 & !!unburntParkY3 & !!Walk3 \
#         4     & !!unburntX4 & !!unburntY4 & !!unburntParkX4 & !!unburntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
#
#
# ewpage
#         \subsubsection{Fire !!id}
#
# egin{table}[h!]
# egin{tabular}{@{}lllll@{}}
#         	oprule
#         id   & Name   & Hectare   & CenterX   & CenterY   \ \midrule
#         !!id & !!name & !!hectare & !!centerX & !!centerY
#         \end{tabular}
#         \end{table}
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingX & Walk(m) \ \midrule
#         1     & !!burntX1 & !!burntY1 & !!burntParkX1 & !!burntParkX1 & !!Walk1 \
#         2     & !!burntX2 & !!burntY2 & !!burntParkX2 & !!burntParkX2 & !!Walk2 \
#         3     & !!burntX3 & !!burntY3 & !!burntParkX3 & !!burntParkY3 & !!Walk3 \
#         4     & !!burntX4 & !!burntY4 & !!burntParkX4 & !!burntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingY & Walk(m) \ \midrule
#         1     & !!unburntX1 & !!unburntY1 & !!unburntParkX1 & !!unburntParkX1 & !!Walk1 \
#         2     & !!unburntX2 & !!unburntY2 & !!unburntParkX2 & !!unburntParkX2 & !!Walk2 \
#         3     & !!unburntX3 & !!unburntY3 & !!unburntParkX3 & !!unburntParkY3 & !!Walk3 \
#         4     & !!unburntX4 & !!unburntY4 & !!unburntParkX4 & !!unburntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
#
#
# ewpage
#         \subsubsection{Fire !!id}
#
# egin{table}[h!]
# egin{tabular}{@{}lllll@{}}
#         	oprule
#         id   & Name   & Hectare   & CenterX   & CenterY   \ \midrule
#         !!id & !!name & !!hectare & !!centerX & !!centerY
#         \end{tabular}
#         \end{table}
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingX & Walk(m) \ \midrule
#         1     & !!burntX1 & !!burntY1 & !!burntParkX1 & !!burntParkX1 & !!Walk1 \
#         2     & !!burntX2 & !!burntY2 & !!burntParkX2 & !!burntParkX2 & !!Walk2 \
#         3     & !!burntX3 & !!burntY3 & !!burntParkX3 & !!burntParkY3 & !!Walk3 \
#         4     & !!burntX4 & !!burntY4 & !!burntParkX4 & !!burntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingY & Walk(m) \ \midrule
#         1     & !!unburntX1 & !!unburntY1 & !!unburntParkX1 & !!unburntParkX1 & !!Walk1 \
#         2     & !!unburntX2 & !!unburntY2 & !!unburntParkX2 & !!unburntParkX2 & !!Walk2 \
#         3     & !!unburntX3 & !!unburntY3 & !!unburntParkX3 & !!unburntParkY3 & !!Walk3 \
#         4     & !!unburntX4 & !!unburntY4 & !!unburntParkX4 & !!unburntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
#
#
# ewpage
#         \subsubsection{Fire !!id}
#
# egin{table}[h!]
# egin{tabular}{@{}lllll@{}}
#         	oprule
#         id   & Name   & Hectare   & CenterX   & CenterY   \ \midrule
#         !!id & !!name & !!hectare & !!centerX & !!centerY
#         \end{tabular}
#         \end{table}
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingX & Walk(m) \ \midrule
#         1     & !!burntX1 & !!burntY1 & !!burntParkX1 & !!burntParkX1 & !!Walk1 \
#         2     & !!burntX2 & !!burntY2 & !!burntParkX2 & !!burntParkX2 & !!Walk2 \
#         3     & !!burntX3 & !!burntY3 & !!burntParkX3 & !!burntParkY3 & !!Walk3 \
#         4     & !!burntX4 & !!burntY4 & !!burntParkX4 & !!burntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingY & Walk(m) \ \midrule
#         1     & !!unburntX1 & !!unburntY1 & !!unburntParkX1 & !!unburntParkX1 & !!Walk1 \
#         2     & !!unburntX2 & !!unburntY2 & !!unburntParkX2 & !!unburntParkX2 & !!Walk2 \
#         3     & !!unburntX3 & !!unburntY3 & !!unburntParkX3 & !!unburntParkY3 & !!Walk3 \
#         4     & !!unburntX4 & !!unburntY4 & !!unburntParkX4 & !!unburntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
#
#
# ewpage
#         \subsubsection{Fire !!id}
#
# egin{table}[h!]
# egin{tabular}{@{}lllll@{}}
#         	oprule
#         id   & Name   & Hectare   & CenterX   & CenterY   \ \midrule
#         !!id & !!name & !!hectare & !!centerX & !!centerY
#         \end{tabular}
#         \end{table}
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingX & Walk(m) \ \midrule
#         1     & !!burntX1 & !!burntY1 & !!burntParkX1 & !!burntParkX1 & !!Walk1 \
#         2     & !!burntX2 & !!burntY2 & !!burntParkX2 & !!burntParkX2 & !!Walk2 \
#         3     & !!burntX3 & !!burntY3 & !!burntParkX3 & !!burntParkY3 & !!Walk3 \
#         4     & !!burntX4 & !!burntY4 & !!burntParkX4 & !!burntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingY & Walk(m) \ \midrule
#         1     & !!unburntX1 & !!unburntY1 & !!unburntParkX1 & !!unburntParkX1 & !!Walk1 \
#         2     & !!unburntX2 & !!unburntY2 & !!unburntParkX2 & !!unburntParkX2 & !!Walk2 \
#         3     & !!unburntX3 & !!unburntY3 & !!unburntParkX3 & !!unburntParkY3 & !!Walk3 \
#         4     & !!unburntX4 & !!unburntY4 & !!unburntParkX4 & !!unburntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
#
#
# ewpage
#         \subsubsection{Fire !!id}
#
# egin{table}[h!]
# egin{tabular}{@{}lllll@{}}
#         	oprule
#         id   & Name   & Hectare   & CenterX   & CenterY   \ \midrule
#         !!id & !!name & !!hectare & !!centerX & !!centerY
#         \end{tabular}
#         \end{table}
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingX & Walk(m) \ \midrule
#         1     & !!burntX1 & !!burntY1 & !!burntParkX1 & !!burntParkX1 & !!Walk1 \
#         2     & !!burntX2 & !!burntY2 & !!burntParkX2 & !!burntParkX2 & !!Walk2 \
#         3     & !!burntX3 & !!burntY3 & !!burntParkX3 & !!burntParkY3 & !!Walk3 \
#         4     & !!burntX4 & !!burntY4 & !!burntParkX4 & !!burntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingY & Walk(m) \ \midrule
#         1     & !!unburntX1 & !!unburntY1 & !!unburntParkX1 & !!unburntParkX1 & !!Walk1 \
#         2     & !!unburntX2 & !!unburntY2 & !!unburntParkX2 & !!unburntParkX2 & !!Walk2 \
#         3     & !!unburntX3 & !!unburntY3 & !!unburntParkX3 & !!unburntParkY3 & !!Walk3 \
#         4     & !!unburntX4 & !!unburntY4 & !!unburntParkX4 & !!unburntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
#
#
# ewpage
#         \subsubsection{Fire !!id}
#
# egin{table}[h!]
# egin{tabular}{@{}lllll@{}}
#         	oprule
#         id   & Name   & Hectare   & CenterX   & CenterY   \ \midrule
#         !!id & !!name & !!hectare & !!centerX & !!centerY
#         \end{tabular}
#         \end{table}
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingX & Walk(m) \ \midrule
#         1     & !!burntX1 & !!burntY1 & !!burntParkX1 & !!burntParkX1 & !!Walk1 \
#         2     & !!burntX2 & !!burntY2 & !!burntParkX2 & !!burntParkX2 & !!Walk2 \
#         3     & !!burntX3 & !!burntY3 & !!burntParkX3 & !!burntParkY3 & !!Walk3 \
#         4     & !!burntX4 & !!burntY4 & !!burntParkX4 & !!burntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingY & Walk(m) \ \midrule
#         1     & !!unburntX1 & !!unburntY1 & !!unburntParkX1 & !!unburntParkX1 & !!Walk1 \
#         2     & !!unburntX2 & !!unburntY2 & !!unburntParkX2 & !!unburntParkX2 & !!Walk2 \
#         3     & !!unburntX3 & !!unburntY3 & !!unburntParkX3 & !!unburntParkY3 & !!Walk3 \
#         4     & !!unburntX4 & !!unburntY4 & !!unburntParkX4 & !!unburntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
#
#
# ewpage
#         \subsubsection{Fire !!id}
#
# egin{table}[h!]
# egin{tabular}{@{}lllll@{}}
#         	oprule
#         id   & Name   & Hectare   & CenterX   & CenterY   \ \midrule
#         !!id & !!name & !!hectare & !!centerX & !!centerY
#         \end{tabular}
#         \end{table}
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingX & Walk(m) \ \midrule
#         1     & !!burntX1 & !!burntY1 & !!burntParkX1 & !!burntParkX1 & !!Walk1 \
#         2     & !!burntX2 & !!burntY2 & !!burntParkX2 & !!burntParkX2 & !!Walk2 \
#         3     & !!burntX3 & !!burntY3 & !!burntParkX3 & !!burntParkY3 & !!Walk3 \
#         4     & !!burntX4 & !!burntY4 & !!burntParkX4 & !!burntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingY & Walk(m) \ \midrule
#         1     & !!unburntX1 & !!unburntY1 & !!unburntParkX1 & !!unburntParkX1 & !!Walk1 \
#         2     & !!unburntX2 & !!unburntY2 & !!unburntParkX2 & !!unburntParkX2 & !!Walk2 \
#         3     & !!unburntX3 & !!unburntY3 & !!unburntParkX3 & !!unburntParkY3 & !!Walk3 \
#         4     & !!unburntX4 & !!unburntY4 & !!unburntParkX4 & !!unburntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
#
#
# ewpage
#         \subsubsection{Fire !!id}
#
# egin{table}[h!]
# egin{tabular}{@{}lllll@{}}
#         	oprule
#         id   & Name   & Hectare   & CenterX   & CenterY   \ \midrule
#         !!id & !!name & !!hectare & !!centerX & !!centerY
#         \end{tabular}
#         \end{table}
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingX & Walk(m) \ \midrule
#         1     & !!burntX1 & !!burntY1 & !!burntParkX1 & !!burntParkX1 & !!Walk1 \
#         2     & !!burntX2 & !!burntY2 & !!burntParkX2 & !!burntParkX2 & !!Walk2 \
#         3     & !!burntX3 & !!burntY3 & !!burntParkX3 & !!burntParkY3 & !!Walk3 \
#         4     & !!burntX4 & !!burntY4 & !!burntParkX4 & !!burntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingY & Walk(m) \ \midrule
#         1     & !!unburntX1 & !!unburntY1 & !!unburntParkX1 & !!unburntParkX1 & !!Walk1 \
#         2     & !!unburntX2 & !!unburntY2 & !!unburntParkX2 & !!unburntParkX2 & !!Walk2 \
#         3     & !!unburntX3 & !!unburntY3 & !!unburntParkX3 & !!unburntParkY3 & !!Walk3 \
#         4     & !!unburntX4 & !!unburntY4 & !!unburntParkX4 & !!unburntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
#
#
# ewpage
#         \subsubsection{Fire !!id}
#
# egin{table}[h!]
# egin{tabular}{@{}lllll@{}}
#         	oprule
#         id   & Name   & Hectare   & CenterX   & CenterY   \ \midrule
#         !!id & !!name & !!hectare & !!centerX & !!centerY
#         \end{tabular}
#         \end{table}
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingX & Walk(m) \ \midrule
#         1     & !!burntX1 & !!burntY1 & !!burntParkX1 & !!burntParkX1 & !!Walk1 \
#         2     & !!burntX2 & !!burntY2 & !!burntParkX2 & !!burntParkX2 & !!Walk2 \
#         3     & !!burntX3 & !!burntY3 & !!burntParkX3 & !!burntParkY3 & !!Walk3 \
#         4     & !!burntX4 & !!burntY4 & !!burntParkX4 & !!burntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingY & Walk(m) \ \midrule
#         1     & !!unburntX1 & !!unburntY1 & !!unburntParkX1 & !!unburntParkX1 & !!Walk1 \
#         2     & !!unburntX2 & !!unburntY2 & !!unburntParkX2 & !!unburntParkX2 & !!Walk2 \
#         3     & !!unburntX3 & !!unburntY3 & !!unburntParkX3 & !!unburntParkY3 & !!Walk3 \
#         4     & !!unburntX4 & !!unburntY4 & !!unburntParkX4 & !!unburntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
#
#
# ewpage
#         \subsubsection{Fire !!id}
#
# egin{table}[h!]
# egin{tabular}{@{}lllll@{}}
#         	oprule
#         id   & Name   & Hectare   & CenterX   & CenterY   \ \midrule
#         !!id & !!name & !!hectare & !!centerX & !!centerY
#         \end{tabular}
#         \end{table}
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingX & Walk(m) \ \midrule
#         1     & !!burntX1 & !!burntY1 & !!burntParkX1 & !!burntParkX1 & !!Walk1 \
#         2     & !!burntX2 & !!burntY2 & !!burntParkX2 & !!burntParkX2 & !!Walk2 \
#         3     & !!burntX3 & !!burntY3 & !!burntParkX3 & !!burntParkY3 & !!Walk3 \
#         4     & !!burntX4 & !!burntY4 & !!burntParkX4 & !!burntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingY & Walk(m) \ \midrule
#         1     & !!unburntX1 & !!unburntY1 & !!unburntParkX1 & !!unburntParkX1 & !!Walk1 \
#         2     & !!unburntX2 & !!unburntY2 & !!unburntParkX2 & !!unburntParkX2 & !!Walk2 \
#         3     & !!unburntX3 & !!unburntY3 & !!unburntParkX3 & !!unburntParkY3 & !!Walk3 \
#         4     & !!unburntX4 & !!unburntY4 & !!unburntParkX4 & !!unburntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
#
#
# ewpage
#         \subsubsection{Fire !!id}
#
# egin{table}[h!]
# egin{tabular}{@{}lllll@{}}
#         	oprule
#         id   & Name   & Hectare   & CenterX   & CenterY   \ \midrule
#         !!id & !!name & !!hectare & !!centerX & !!centerY
#         \end{tabular}
#         \end{table}
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingX & Walk(m) \ \midrule
#         1     & !!burntX1 & !!burntY1 & !!burntParkX1 & !!burntParkX1 & !!Walk1 \
#         2     & !!burntX2 & !!burntY2 & !!burntParkX2 & !!burntParkX2 & !!Walk2 \
#         3     & !!burntX3 & !!burntY3 & !!burntParkX3 & !!burntParkY3 & !!Walk3 \
#         4     & !!burntX4 & !!burntY4 & !!burntParkX4 & !!burntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingY & Walk(m) \ \midrule
#         1     & !!unburntX1 & !!unburntY1 & !!unburntParkX1 & !!unburntParkX1 & !!Walk1 \
#         2     & !!unburntX2 & !!unburntY2 & !!unburntParkX2 & !!unburntParkX2 & !!Walk2 \
#         3     & !!unburntX3 & !!unburntY3 & !!unburntParkX3 & !!unburntParkY3 & !!Walk3 \
#         4     & !!unburntX4 & !!unburntY4 & !!unburntParkX4 & !!unburntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
#
#
# ewpage
#         \subsubsection{Fire !!id}
#
# egin{table}[h!]
# egin{tabular}{@{}lllll@{}}
#         	oprule
#         id   & Name   & Hectare   & CenterX   & CenterY   \ \midrule
#         !!id & !!name & !!hectare & !!centerX & !!centerY
#         \end{tabular}
#         \end{table}
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingX & Walk(m) \ \midrule
#         1     & !!burntX1 & !!burntY1 & !!burntParkX1 & !!burntParkX1 & !!Walk1 \
#         2     & !!burntX2 & !!burntY2 & !!burntParkX2 & !!burntParkX2 & !!Walk2 \
#         3     & !!burntX3 & !!burntY3 & !!burntParkX3 & !!burntParkY3 & !!Walk3 \
#         4     & !!burntX4 & !!burntY4 & !!burntParkX4 & !!burntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingY & Walk(m) \ \midrule
#         1     & !!unburntX1 & !!unburntY1 & !!unburntParkX1 & !!unburntParkX1 & !!Walk1 \
#         2     & !!unburntX2 & !!unburntY2 & !!unburntParkX2 & !!unburntParkX2 & !!Walk2 \
#         3     & !!unburntX3 & !!unburntY3 & !!unburntParkX3 & !!unburntParkY3 & !!Walk3 \
#         4     & !!unburntX4 & !!unburntY4 & !!unburntParkX4 & !!unburntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
#
#
# ewpage
#         \subsubsection{Fire !!id}
#
# egin{table}[h!]
# egin{tabular}{@{}lllll@{}}
#         	oprule
#         id   & Name   & Hectare   & CenterX   & CenterY   \ \midrule
#         !!id & !!name & !!hectare & !!centerX & !!centerY
#         \end{tabular}
#         \end{table}
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingX & Walk(m) \ \midrule
#         1     & !!burntX1 & !!burntY1 & !!burntParkX1 & !!burntParkX1 & !!Walk1 \
#         2     & !!burntX2 & !!burntY2 & !!burntParkX2 & !!burntParkX2 & !!Walk2 \
#         3     & !!burntX3 & !!burntY3 & !!burntParkX3 & !!burntParkY3 & !!Walk3 \
#         4     & !!burntX4 & !!burntY4 & !!burntParkX4 & !!burntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingY & Walk(m) \ \midrule
#         1     & !!unburntX1 & !!unburntY1 & !!unburntParkX1 & !!unburntParkX1 & !!Walk1 \
#         2     & !!unburntX2 & !!unburntY2 & !!unburntParkX2 & !!unburntParkX2 & !!Walk2 \
#         3     & !!unburntX3 & !!unburntY3 & !!unburntParkX3 & !!unburntParkY3 & !!Walk3 \
#         4     & !!unburntX4 & !!unburntY4 & !!unburntParkX4 & !!unburntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
#
#
# ewpage
#         \subsubsection{Fire !!id}
#
# egin{table}[h!]
# egin{tabular}{@{}lllll@{}}
#         	oprule
#         id   & Name   & Hectare   & CenterX   & CenterY   \ \midrule
#         !!id & !!name & !!hectare & !!centerX & !!centerY
#         \end{tabular}
#         \end{table}
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingX & Walk(m) \ \midrule
#         1     & !!burntX1 & !!burntY1 & !!burntParkX1 & !!burntParkX1 & !!Walk1 \
#         2     & !!burntX2 & !!burntY2 & !!burntParkX2 & !!burntParkX2 & !!Walk2 \
#         3     & !!burntX3 & !!burntY3 & !!burntParkX3 & !!burntParkY3 & !!Walk3 \
#         4     & !!burntX4 & !!burntY4 & !!burntParkX4 & !!burntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingY & Walk(m) \ \midrule
#         1     & !!unburntX1 & !!unburntY1 & !!unburntParkX1 & !!unburntParkX1 & !!Walk1 \
#         2     & !!unburntX2 & !!unburntY2 & !!unburntParkX2 & !!unburntParkX2 & !!Walk2 \
#         3     & !!unburntX3 & !!unburntY3 & !!unburntParkX3 & !!unburntParkY3 & !!Walk3 \
#         4     & !!unburntX4 & !!unburntY4 & !!unburntParkX4 & !!unburntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
#
#
# ewpage
#         \subsubsection{Fire !!id}
#
# egin{table}[h!]
# egin{tabular}{@{}lllll@{}}
#         	oprule
# ...
#         1     & !!burntX1 & !!burntY1 & !!burntParkX1 & !!burntParkX1 & !!Walk1 \
#         2     & !!burntX2 & !!burntY2 & !!burntParkX2 & !!burntParkX2 & !!Walk2 \
#         3     & !!burntX3 & !!burntY3 & !!burntParkX3 & !!burntParkY3 & !!Walk3 \
#         4     & !!burntX4 & !!burntY4 & !!burntParkX4 & !!burntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingY & Walk(m) \ \midrule
#         1     & !!unburntX1 & !!unburntY1 & !!unburntParkX1 & !!unburntParkX1 & !!Walk1 \
#         2     & !!unburntX2 & !!unburntY2 & !!unburntParkX2 & !!unburntParkX2 & !!Walk2 \
#         3     & !!unburntX3 & !!unburntY3 & !!unburntParkX3 & !!unburntParkY3 & !!Walk3 \
#         4     & !!unburntX4 & !!unburntY4 & !!unburntParkX4 & !!unburntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
#
#
# ewpage
#         \subsubsection{Fire !!id}
#
# egin{table}[h!]
# egin{tabular}{@{}lllll@{}}
#         	oprule
#         id   & Name   & Hectare   & CenterX   & CenterY   \ \midrule
#         !!id & !!name & !!hectare & !!centerX & !!centerY
#         \end{tabular}
#         \end{table}
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingX & Walk(m) \ \midrule
#         1     & !!burntX1 & !!burntY1 & !!burntParkX1 & !!burntParkX1 & !!Walk1 \
#         2     & !!burntX2 & !!burntY2 & !!burntParkX2 & !!burntParkX2 & !!Walk2 \
#         3     & !!burntX3 & !!burntY3 & !!burntParkX3 & !!burntParkY3 & !!Walk3 \
#         4     & !!burntX4 & !!burntY4 & !!burntParkX4 & !!burntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingY & Walk(m) \ \midrule
#         1     & !!unburntX1 & !!unburntY1 & !!unburntParkX1 & !!unburntParkX1 & !!Walk1 \
#         2     & !!unburntX2 & !!unburntY2 & !!unburntParkX2 & !!unburntParkX2 & !!Walk2 \
#         3     & !!unburntX3 & !!unburntY3 & !!unburntParkX3 & !!unburntParkY3 & !!Walk3 \
#         4     & !!unburntX4 & !!unburntY4 & !!unburntParkX4 & !!unburntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
#
#
# ewpage
#         \subsubsection{Fire !!id}
#
# egin{table}[h!]
# egin{tabular}{@{}lllll@{}}
#         	oprule
#         id   & Name   & Hectare   & CenterX   & CenterY   \ \midrule
#         !!id & !!name & !!hectare & !!centerX & !!centerY
#         \end{tabular}
#         \end{table}
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingX & Walk(m) \ \midrule
#         1     & !!burntX1 & !!burntY1 & !!burntParkX1 & !!burntParkX1 & !!Walk1 \
#         2     & !!burntX2 & !!burntY2 & !!burntParkX2 & !!burntParkX2 & !!Walk2 \
#         3     & !!burntX3 & !!burntY3 & !!burntParkX3 & !!burntParkY3 & !!Walk3 \
#         4     & !!burntX4 & !!burntY4 & !!burntParkX4 & !!burntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingY & Walk(m) \ \midrule
#         1     & !!unburntX1 & !!unburntY1 & !!unburntParkX1 & !!unburntParkX1 & !!Walk1 \
#         2     & !!unburntX2 & !!unburntY2 & !!unburntParkX2 & !!unburntParkX2 & !!Walk2 \
#         3     & !!unburntX3 & !!unburntY3 & !!unburntParkX3 & !!unburntParkY3 & !!Walk3 \
#         4     & !!unburntX4 & !!unburntY4 & !!unburntParkX4 & !!unburntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
#
#
# ewpage
#         \subsubsection{Fire !!id}
#
# egin{table}[h!]
# egin{tabular}{@{}lllll@{}}
#         	oprule
#         id   & Name   & Hectare   & CenterX   & CenterY   \ \midrule
#         !!id & !!name & !!hectare & !!centerX & !!centerY
#         \end{tabular}
#         \end{table}
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingX & Walk(m) \ \midrule
#         1     & !!burntX1 & !!burntY1 & !!burntParkX1 & !!burntParkX1 & !!Walk1 \
#         2     & !!burntX2 & !!burntY2 & !!burntParkX2 & !!burntParkX2 & !!Walk2 \
#         3     & !!burntX3 & !!burntY3 & !!burntParkX3 & !!burntParkY3 & !!Walk3 \
#         4     & !!burntX4 & !!burntY4 & !!burntParkX4 & !!burntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingY & Walk(m) \ \midrule
#         1     & !!unburntX1 & !!unburntY1 & !!unburntParkX1 & !!unburntParkX1 & !!Walk1 \
#         2     & !!unburntX2 & !!unburntY2 & !!unburntParkX2 & !!unburntParkX2 & !!Walk2 \
#         3     & !!unburntX3 & !!unburntY3 & !!unburntParkX3 & !!unburntParkY3 & !!Walk3 \
#         4     & !!unburntX4 & !!unburntY4 & !!unburntParkX4 & !!unburntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
#
#
# ewpage
#         \subsubsection{Fire !!id}
#
# egin{table}[h!]
# egin{tabular}{@{}lllll@{}}
#         	oprule
#         id   & Name   & Hectare   & CenterX   & CenterY   \ \midrule
#         !!id & !!name & !!hectare & !!centerX & !!centerY
#         \end{tabular}
#         \end{table}
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingX & Walk(m) \ \midrule
#         1     & !!burntX1 & !!burntY1 & !!burntParkX1 & !!burntParkX1 & !!Walk1 \
#         2     & !!burntX2 & !!burntY2 & !!burntParkX2 & !!burntParkX2 & !!Walk2 \
#         3     & !!burntX3 & !!burntY3 & !!burntParkX3 & !!burntParkY3 & !!Walk3 \
#         4     & !!burntX4 & !!burntY4 & !!burntParkX4 & !!burntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingY & Walk(m) \ \midrule
#         1     & !!unburntX1 & !!unburntY1 & !!unburntParkX1 & !!unburntParkX1 & !!Walk1 \
#         2     & !!unburntX2 & !!unburntY2 & !!unburntParkX2 & !!unburntParkX2 & !!Walk2 \
#         3     & !!unburntX3 & !!unburntY3 & !!unburntParkX3 & !!unburntParkY3 & !!Walk3 \
#         4     & !!unburntX4 & !!unburntY4 & !!unburntParkX4 & !!unburntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
#
#
# ewpage
#         \subsubsection{Fire !!id}
#
# egin{table}[h!]
# egin{tabular}{@{}lllll@{}}
#         	oprule
#         id   & Name   & Hectare   & CenterX   & CenterY   \ \midrule
#         !!id & !!name & !!hectare & !!centerX & !!centerY
#         \end{tabular}
#         \end{table}
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingX & Walk(m) \ \midrule
#         1     & !!burntX1 & !!burntY1 & !!burntParkX1 & !!burntParkX1 & !!Walk1 \
#         2     & !!burntX2 & !!burntY2 & !!burntParkX2 & !!burntParkX2 & !!Walk2 \
#         3     & !!burntX3 & !!burntY3 & !!burntParkX3 & !!burntParkY3 & !!Walk3 \
#         4     & !!burntX4 & !!burntY4 & !!burntParkX4 & !!burntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingY & Walk(m) \ \midrule
#         1     & !!unburntX1 & !!unburntY1 & !!unburntParkX1 & !!unburntParkX1 & !!Walk1 \
#         2     & !!unburntX2 & !!unburntY2 & !!unburntParkX2 & !!unburntParkX2 & !!Walk2 \
#         3     & !!unburntX3 & !!unburntY3 & !!unburntParkX3 & !!unburntParkY3 & !!Walk3 \
#         4     & !!unburntX4 & !!unburntY4 & !!unburntParkX4 & !!unburntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
#
#
# ewpage
#         \subsubsection{Fire !!id}
#
# egin{table}[h!]
# egin{tabular}{@{}lllll@{}}
#         	oprule
#         id   & Name   & Hectare   & CenterX   & CenterY   \ \midrule
#         !!id & !!name & !!hectare & !!centerX & !!centerY
#         \end{tabular}
#         \end{table}
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingX & Walk(m) \ \midrule
#         1     & !!burntX1 & !!burntY1 & !!burntParkX1 & !!burntParkX1 & !!Walk1 \
#         2     & !!burntX2 & !!burntY2 & !!burntParkX2 & !!burntParkX2 & !!Walk2 \
#         3     & !!burntX3 & !!burntY3 & !!burntParkX3 & !!burntParkY3 & !!Walk3 \
#         4     & !!burntX4 & !!burntY4 & !!burntParkX4 & !!burntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingY & Walk(m) \ \midrule
#         1     & !!unburntX1 & !!unburntY1 & !!unburntParkX1 & !!unburntParkX1 & !!Walk1 \
#         2     & !!unburntX2 & !!unburntY2 & !!unburntParkX2 & !!unburntParkX2 & !!Walk2 \
#         3     & !!unburntX3 & !!unburntY3 & !!unburntParkX3 & !!unburntParkY3 & !!Walk3 \
#         4     & !!unburntX4 & !!unburntY4 & !!unburntParkX4 & !!unburntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
#
#
# ewpage
#         \subsubsection{Fire !!id}
#
# egin{table}[h!]
# egin{tabular}{@{}lllll@{}}
#         	oprule
#         id   & Name   & Hectare   & CenterX   & CenterY   \ \midrule
#         !!id & !!name & !!hectare & !!centerX & !!centerY
#         \end{tabular}
#         \end{table}
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingX & Walk(m) \ \midrule
#         1     & !!burntX1 & !!burntY1 & !!burntParkX1 & !!burntParkX1 & !!Walk1 \
#         2     & !!burntX2 & !!burntY2 & !!burntParkX2 & !!burntParkX2 & !!Walk2 \
#         3     & !!burntX3 & !!burntY3 & !!burntParkX3 & !!burntParkY3 & !!Walk3 \
#         4     & !!burntX4 & !!burntY4 & !!burntParkX4 & !!burntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingY & Walk(m) \ \midrule
#         1     & !!unburntX1 & !!unburntY1 & !!unburntParkX1 & !!unburntParkX1 & !!Walk1 \
#         2     & !!unburntX2 & !!unburntY2 & !!unburntParkX2 & !!unburntParkX2 & !!Walk2 \
#         3     & !!unburntX3 & !!unburntY3 & !!unburntParkX3 & !!unburntParkY3 & !!Walk3 \
#         4     & !!unburntX4 & !!unburntY4 & !!unburntParkX4 & !!unburntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
#
#
# ewpage
#         \subsubsection{Fire !!id}
#
# egin{table}[h!]
# egin{tabular}{@{}lllll@{}}
#         	oprule
#         id   & Name   & Hectare   & CenterX   & CenterY   \ \midrule
#         !!id & !!name & !!hectare & !!centerX & !!centerY
#         \end{tabular}
#         \end{table}
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingX & Walk(m) \ \midrule
#         1     & !!burntX1 & !!burntY1 & !!burntParkX1 & !!burntParkX1 & !!Walk1 \
#         2     & !!burntX2 & !!burntY2 & !!burntParkX2 & !!burntParkX2 & !!Walk2 \
#         3     & !!burntX3 & !!burntY3 & !!burntParkX3 & !!burntParkY3 & !!Walk3 \
#         4     & !!burntX4 & !!burntY4 & !!burntParkX4 & !!burntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingY & Walk(m) \ \midrule
#         1     & !!unburntX1 & !!unburntY1 & !!unburntParkX1 & !!unburntParkX1 & !!Walk1 \
#         2     & !!unburntX2 & !!unburntY2 & !!unburntParkX2 & !!unburntParkX2 & !!Walk2 \
#         3     & !!unburntX3 & !!unburntY3 & !!unburntParkX3 & !!unburntParkY3 & !!Walk3 \
#         4     & !!unburntX4 & !!unburntY4 & !!unburntParkX4 & !!unburntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
#
#
# ewpage
#         \subsubsection{Fire !!id}
#
# egin{table}[h!]
# egin{tabular}{@{}lllll@{}}
#         	oprule
#         id   & Name   & Hectare   & CenterX   & CenterY   \ \midrule
#         !!id & !!name & !!hectare & !!centerX & !!centerY
#         \end{tabular}
#         \end{table}
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingX & Walk(m) \ \midrule
#         1     & !!burntX1 & !!burntY1 & !!burntParkX1 & !!burntParkX1 & !!Walk1 \
#         2     & !!burntX2 & !!burntY2 & !!burntParkX2 & !!burntParkX2 & !!Walk2 \
#         3     & !!burntX3 & !!burntY3 & !!burntParkX3 & !!burntParkY3 & !!Walk3 \
#         4     & !!burntX4 & !!burntY4 & !!burntParkX4 & !!burntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingY & Walk(m) \ \midrule
#         1     & !!unburntX1 & !!unburntY1 & !!unburntParkX1 & !!unburntParkX1 & !!Walk1 \
#         2     & !!unburntX2 & !!unburntY2 & !!unburntParkX2 & !!unburntParkX2 & !!Walk2 \
#         3     & !!unburntX3 & !!unburntY3 & !!unburntParkX3 & !!unburntParkY3 & !!Walk3 \
#         4     & !!unburntX4 & !!unburntY4 & !!unburntParkX4 & !!unburntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
#
#
# ewpage
#         \subsubsection{Fire !!id}
#
# egin{table}[h!]
# egin{tabular}{@{}lllll@{}}
#         	oprule
#         id   & Name   & Hectare   & CenterX   & CenterY   \ \midrule
#         !!id & !!name & !!hectare & !!centerX & !!centerY
#         \end{tabular}
#         \end{table}
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingX & Walk(m) \ \midrule
#         1     & !!burntX1 & !!burntY1 & !!burntParkX1 & !!burntParkX1 & !!Walk1 \
#         2     & !!burntX2 & !!burntY2 & !!burntParkX2 & !!burntParkX2 & !!Walk2 \
#         3     & !!burntX3 & !!burntY3 & !!burntParkX3 & !!burntParkY3 & !!Walk3 \
#         4     & !!burntX4 & !!burntY4 & !!burntParkX4 & !!burntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingY & Walk(m) \ \midrule
#         1     & !!unburntX1 & !!unburntY1 & !!unburntParkX1 & !!unburntParkX1 & !!Walk1 \
#         2     & !!unburntX2 & !!unburntY2 & !!unburntParkX2 & !!unburntParkX2 & !!Walk2 \
#         3     & !!unburntX3 & !!unburntY3 & !!unburntParkX3 & !!unburntParkY3 & !!Walk3 \
#         4     & !!unburntX4 & !!unburntY4 & !!unburntParkX4 & !!unburntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
#
#
# ewpage
#         \subsubsection{Fire !!id}
#
# egin{table}[h!]
# egin{tabular}{@{}lllll@{}}
#         	oprule
#         id   & Name   & Hectare   & CenterX   & CenterY   \ \midrule
#         !!id & !!name & !!hectare & !!centerX & !!centerY
#         \end{tabular}
#         \end{table}
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingX & Walk(m) \ \midrule
#         1     & !!burntX1 & !!burntY1 & !!burntParkX1 & !!burntParkX1 & !!Walk1 \
#         2     & !!burntX2 & !!burntY2 & !!burntParkX2 & !!burntParkX2 & !!Walk2 \
#         3     & !!burntX3 & !!burntY3 & !!burntParkX3 & !!burntParkY3 & !!Walk3 \
#         4     & !!burntX4 & !!burntY4 & !!burntParkX4 & !!burntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
#
#
# egin{table}[h!]
# egin{tabular}{@{}llllll@{}}
#         	oprule
#         Patch & X         & Y         & ParkingX & ParkingY & Walk(m) \ \midrule
#         1     & !!unburntX1 & !!unburntY1 & !!unburntParkX1 & !!unburntParkX1 & !!Walk1 \
#         2     & !!unburntX2 & !!unburntY2 & !!unburntParkX2 & !!unburntParkX2 & !!Walk2 \
#         3     & !!unburntX3 & !!unburntY3 & !!unburntParkX3 & !!unburntParkY3 & !!Walk3 \
#         4     & !!unburntX4 & !!unburntY4 & !!unburntParkX4 & !!unburntParkY4 & !!Walk4 \
# ottomrule
#         \end{tabular}
#         \end{table}
